# %% [markdown]
# 1. Import required libraries and read the dataset.

# %%
import pandas as pd
data = pd.read_csv("Apps_data.csv")
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
# Check the first few samples (head of the DataFrame)
print("First Few Samples:")
print(data.head())
# Calculating bottom 5 Rows of the dataset.
print("Last Few Samples:")
print(data.tail())
# Check the shape of the DataFrame
print("\nDataFrame Shape:", data.shape)
# Check the basic information about the DataFrame (data types, non-null counts, etc.)
print("\nDataFrame Info:")
print(data.info())
# Out:
# First Few Samples:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# Last Few Samples:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# DataFrame Shape: (10841, 13)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# 3. Check summary statistics of the dataset. List out the columns that need to be worked upon for model
# building.

# %%
# Check summary statistics of the dataset
summary_stats = data.describe()

# Display the summary statistics
print("Summary Statistics of the Dataset:")
print(summary_stats)
# Out:
# Summary Statistics of the Dataset:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#Calculating Desciptive statistics of all the features.
data.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %%
"""The Features that are required to be worked upon for model building are : """
print("1.. Rating")
print("2. Type")
print("3. Content Rating")
print("4. Price")
print("5. Category")
print("6. Reviews")
# Out:
# 'The Features that are required to be worked upon for model building are : '
# 1.. Rating
# 2. Type
# 3. Content Rating
# 4. Price
# 5. Category
# 6. Reviews

# %% [markdown]
# 4.Check if there are any duplicate records in the dataset? if any drop them.

# %%
#Finding duplicate Records.
duplicates = data[data.duplicated()]

# %%
duplicates
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 229      80805  Varies with device    5,000,000+  Free     0       Everyone
# 236     159872  Varies with device   10,000,000+  Free     0       Everyone
# 239      70991  Varies with device    5,000,000+  Free     0       Everyone
# 256      31614                 37M   10,000,000+  Free     0       Everyone
# 261       6989  Varies with device    1,000,000+  Free     0       Everyone
# ...        ...                 ...           ...   ...   ...            ...
# 8643    404610  Varies with device   10,000,000+  Free     0       Everyone
# 8654     25370  Varies with device    1,000,000+  Free     0       Everyone
# 8658   2401017  Varies with device  100,000,000+  Free     0       Everyone
# 10049      123                 86M       10,000+  Free     0       Everyone
# 10768       63                 24M       10,000+  Free     0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 229        Business  February 26, 2018  Varies with device        4.0.3 and up
# 236        Business      July 31, 2018  Varies with device  Varies with device
# 239        Business      July 24, 2018    2.19.0.204537701          4.4 and up
# 256        Business      July 20, 2018      4.1.28165.0716          4.0 and up
# 261        Business      July 16, 2018           4.3.0.508          4.4 and up
# ...             ...                ...                 ...                 ...
# 8643   Productivity      April 6, 2018  Varies with device  Varies with device
# 8654   Productivity     August 6, 2018  Varies with device  Varies with device
# 8658   Productivity      June 27, 2018  Varies with device  Varies with device
# 10049       Medical       June 1, 2018              0.6.88          5.0 and up
# 10768       Medical      June 22, 2018               2.3.1          5.0 and up
#
# [483 rows x 13 columns]

# %%
# Dropping all the duplicate records in the data
data.drop_duplicates(inplace=True)

# %%
# Recalculating the shape of the dataset
data.shape
# Out:
# (10358, 13)

# %% [markdown]
# 5.Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them.

# %%
# Getting all the unique categories from Category Column
data.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
invalid_data= data[data["Category"]=="1.9"]

# %%
print("Invalid Category:-")
invalid_data
# Out:
# Invalid Category:-
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data.drop(10472,inplace=True)

# %%
data.shape
# Out:
# (10357, 13)

# %%
data.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# 6. Check if there are missing values present in the column Rating, If any? drop them and and create a new
# column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

# %%
print("The total number of rows in the column Rating is :" , data.shape[0])
print("The count of missing values present in the column Rating is :",data.Rating.isna().sum())
# Out:
# The total number of rows in the column Rating is : 10357
# The count of missing values present in the column Rating is : 1465

# %%
#Finding indexes records with missing ratings.
blank_rating = data[data["Rating"].isna()].index

# %%
blank_rating
# Out:
# Int64Index([   23,   113,   123,   126,   129,   130,   134,   163,   180,
#               185,
#             ...
#             10816, 10818, 10821, 10822, 10823, 10824, 10825, 10831, 10835,
#             10838],
#            dtype='int64', length=1465)

# %%
##Dropping off records with missing rating
data.drop(blank_rating, inplace=True)

# %%
print("Rows:-")
data.shape[0]
# Out:
# Rows:-
# 8892

# %%
print("columns:-")
data.shape[1]
# Out:
# columns:-
# 13

# %%
# Defining a fuction to classify the ratings.
def Rating_category(value):
    if value <= 3.5:
        return "Low"
    elif value > 3.5:
        return "High"

# %%
# Creating the column Rating_category and classifying records.
data["Rating_category"] = data['Rating'].map(Rating_category)

# %%
data.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#   Reviews Size Installs  Type Price Content Rating        Genres  \
# 0     159  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver Rating_category
# 0  January 7, 2018       1.0.0  4.0.3 and up            High

# %% [markdown]
# 7. Check the distribution of the newly created column 'Rating_category' and comment on the distribution.

# %%
#Distribution of Rating_category
distribution = data["Rating_category"].value_counts()

# %%
distribution
# Out:
# High    8012
# Low      880
# Name: Rating_category, dtype: int64

# %%
import matplotlib.pyplot as plt
#plotting a histogram to see the distribution
data["Rating_category"].hist()
plt.title("Distribution of Rating_category")
# Out:
# <Axes: >
# Text(0.5, 1.0, 'Distribution of Rating_category')

# %% [markdown]
# It can be inferred that the Rating_category column has maximum Count of High and a very minimal count of Low. The figure's says that there are 8013 apps under High category and only 880 apps under Low category.

# %% [markdown]
# 8.Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and handle the outliers using a transformation approach.(Hint: Use log transformation)

# %%
type(data["Reviews"])
# Out:
# pandas.core.series.Series

# %%
# Checking datatype of Reviesws Column
data["Reviews"].dtypes
# Out:
# dtype('O')

# %%
data[data["Reviews"] == "3.0M"]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Rating_category]
# Index: []

# %%
data["Reviews"] = data["Reviews"].str.replace(".0M","000000")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16808\1628269787.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Reviews"] = data["Reviews"].str.replace(".0M","000000")

# %%
# Changing the datatype to integer for performing Transformation.
data["Reviews"] = data["Reviews"].astype(int)

# %%
data.dtypes["Reviews"]
# Out:
# dtype('int32')

# %%
data["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10834         7
# 10836        38
# 10837         4
# 10839       114
# 10840    398307
# Name: Reviews, Length: 8892, dtype: int32

# %%
# Seeing the Descriptive Statistics.
data.Reviews.describe()
# Out:
# count    8.892000e+03
# mean     4.727764e+05
# std      2.905052e+06
# min      1.000000e+00
# 25%      1.640000e+02
# 50%      4.714500e+03
# 75%      7.126675e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
import seaborn as sns
sns.boxplot(data["Reviews"])
# Out:
# <Axes: >

# %%
import numpy as np
# Applying Log Transformation to the column using Log10.
log10 = np.log10(data["Reviews"])

# %%
# Checking The Descriptive Statistics after applying Log Transformation.
log10.describe()
# Out:
# count    8892.000000
# mean        3.576368
# std         1.685149
# min         0.000000
# 25%         2.214844
# 50%         3.673435
# 75%         4.852887
# max         7.892975
# Name: Reviews, dtype: float64

# %%
# Plotting a boxplot to Analyze any Outliers
sns.boxplot(log10, color="violet" , showmeans = True)
plt.title("BoxPlot for Analyzing Outlier's after Log transformation.")
# Out:
# <Axes: >
# Text(0.5, 1.0, "BoxPlot for Analyzing Outlier's after Log transformation.")

# %%
# Replacing reviews values with their transformed values.
data["Reviews"] = log10

# %%
data.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#     Reviews Size Installs  Type Price Content Rating        Genres  \
# 0  2.201397  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver Rating_category
# 0  January 7, 2018       1.0.0  4.0.3 and up            High

# %% [markdown]
# After changing the datatype of Reviews column from object to int datatype and applying the Log Transformation to analyze  and handle any outliers. Further creating a boxplot to View if there are any outlier's after log transformation. As a result of all above transformations there is no outlier present in the dataset after log transformation.

# %% [markdown]
# 9. The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into
# suitable data type. (hint: Replace M with 1 million and K with 1 thousand, and drop the entries where
# size='Varies with device')

# %%
data["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10834                  2.6M
# 10836                   53M
# 10837                  3.6M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 8892, dtype: object

# %%
data["Size"] = data["Size"].apply(lambda x : x.replace(",",""))

# %%
# Replacing alphabetical to numerical
data["Size"] = data["Size"].str.replace("M","000000")

# %%
data["Size"] = data["Size"].str.replace("k","000")

# %%
# Finding the idexes of records having Size "Varies_with_device".
Varies_with_device = data[data["Size"] == "Varies with device"].index

# %%
Varies_with_device
# Out:
# Int64Index([   37,    42,    52,    67,    68,    73,    85,    88,    89,
#                92,
#             ...
#             10647, 10679, 10681, 10707, 10712, 10713, 10725, 10765, 10826,
#             10839],
#            dtype='int64', length=1468)

# %%
#dropping records having Size "Varies_with_device".
data.drop(Varies_with_device,inplace=True)

# %%
# Checking the number of rows present in the dataset now.
data.shape[0]
# Out:
# 7424

# %%
# Conversion of column named SIZE from Object dtype to the best Suitable dtype.
data["Size"].convert_dtypes()
# Out:
# 0         19000000
# 1         14000000
# 2        8.7000000
# 3         25000000
# 4        2.8000000
#            ...
# 10833       619000
# 10834    2.6000000
# 10836     53000000
# 10837    3.6000000
# 10840     19000000
# Name: Size, Length: 7424, dtype: string

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews       Size     Installs  Type Price Content Rating  \
# 0         4.1  2.201397   19000000      10,000+  Free     0       Everyone
# 1         3.9  2.985426   14000000     500,000+  Free     0       Everyone
# 2         4.7  4.942058  8.7000000   5,000,000+  Free     0       Everyone
# 3         4.5  5.333737   25000000  50,000,000+  Free     0           Teen
# 4         4.3  2.985426  2.8000000     100,000+  Free     0       Everyone
# ...       ...       ...        ...          ...   ...   ...            ...
# 10833     4.8  1.643453     619000       1,000+  Free     0       Everyone
# 10834     4.0  0.845098  2.6000000         500+  Free     0       Everyone
# 10836     4.5  1.579784   53000000       5,000+  Free     0       Everyone
# 10837     5.0  0.602060  3.6000000         100+  Free     0       Everyone
# 10840     4.5  5.600218   19000000  10,000,000+  Free     0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10833          Books & Reference    March 23, 2014                 0.8
# 10834                  Education     June 18, 2017               1.0.0
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver Rating_category
# 0            4.0.3 and up            High
# 1            4.0.3 and up            High
# 2            4.0.3 and up            High
# 3              4.2 and up            High
# 4              4.4 and up            High
# ...                   ...             ...
# 10833          2.2 and up            High
# 10834          4.1 and up            High
# 10836          4.1 and up            High
# 10837          4.1 and up            High
# 10840  Varies with device            High
#
# [7424 rows x 14 columns]

# %% [markdown]
# 10. Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
data["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10833         1,000+
# 10834           500+
# 10836         5,000+
# 10837           100+
# 10840    10,000,000+
# Name: Installs, Length: 7424, dtype: object

# %%
#Replacing the Unwanted Characters in the dataset 
data["Installs"] = data["Installs"].str.replace("+","").replace(",","")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16808\3105114775.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Installs"] = data["Installs"].str.replace("+","").replace(",","")

# %%
# Calling the column after Replacing unwanted characters.
data["Installs"]
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10833         1,000
# 10834           500
# 10836         5,000
# 10837           100
# 10840    10,000,000
# Name: Installs, Length: 7424, dtype: object

# %%
# Conversion of column named Installs from Object dtype to the best Suitable dtype.
data["Installs"].convert_dtypes()
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10833         1,000
# 10834           500
# 10836         5,000
# 10837           100
# 10840    10,000,000
# Name: Installs, Length: 7424, dtype: string

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews       Size    Installs  Type Price Content Rating  \
# 0  2.201397   19000000      10,000  Free     0       Everyone
# 1  2.985426   14000000     500,000  Free     0       Everyone
# 2  4.942058  8.7000000   5,000,000  Free     0       Everyone
# 3  5.333737   25000000  50,000,000  Free     0           Teen
# 4  2.985426  2.8000000     100,000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver Rating_category
# 0  4.0.3 and up            High
# 1  4.0.3 and up            High
# 2  4.0.3 and up            High
# 3    4.2 and up            High
# 4    4.4 and up            High

# %% [markdown]
# 11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

# %%
data["Price"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10833    0
# 10834    0
# 10836    0
# 10837    0
# 10840    0
# Name: Price, Length: 7424, dtype: object

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews       Size    Installs  Type Price Content Rating  \
# 0         4.1  2.201397   19000000      10,000  Free     0       Everyone
# 1         3.9  2.985426   14000000     500,000  Free     0       Everyone
# 2         4.7  4.942058  8.7000000   5,000,000  Free     0       Everyone
# 3         4.5  5.333737   25000000  50,000,000  Free     0           Teen
# 4         4.3  2.985426  2.8000000     100,000  Free     0       Everyone
# ...       ...       ...        ...         ...   ...   ...            ...
# 10833     4.8  1.643453     619000       1,000  Free     0       Everyone
# 10834     4.0  0.845098  2.6000000         500  Free     0       Everyone
# 10836     4.5  1.579784   53000000       5,000  Free     0       Everyone
# 10837     5.0  0.602060  3.6000000         100  Free     0       Everyone
# 10840     4.5  5.600218   19000000  10,000,000  Free     0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10833          Books & Reference    March 23, 2014                 0.8
# 10834                  Education     June 18, 2017               1.0.0
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver Rating_category
# 0            4.0.3 and up            High
# 1            4.0.3 and up            High
# 2            4.0.3 and up            High
# 3              4.2 and up            High
# 4              4.4 and up            High
# ...                   ...             ...
# 10833          2.2 and up            High
# 10834          4.1 and up            High
# 10836          4.1 and up            High
# 10837          4.1 and up            High
# 10840  Varies with device            High
#
# [7424 rows x 14 columns]

# %%
data["Price"].unique()
# Out:
# array(['0', '$4.99', '$6.99', '$7.99', '$3.99', '$5.99', '$2.99', '$1.99',
#        '$9.99', '$0.99', '$9.00', '$5.49', '$10.00', '$24.99', '$11.99',
#        '$79.99', '$16.99', '$14.99', '$29.99', '$12.99', '$3.49',
#        '$10.99', '$7.49', '$1.50', '$19.99', '$15.99', '$33.99', '$39.99',
#        '$2.49', '$4.49', '$1.70', '$1.49', '$3.88', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$1.59',
#        '$6.49', '$1.29', '$299.99', '$379.99', '$37.99', '$18.99',
#        '$389.99', '$8.49', '$1.75', '$14.00', '$2.00', '$3.08', '$2.59',
#        '$19.40', '$15.46', '$8.99', '$3.04', '$13.99', '$4.29', '$3.28',
#        '$4.60', '$1.00', '$2.90', '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
data["Price"] = data["Price"].apply(lambda x : x.replace(",",""))

# %%
#Replacing the Unwanted Characters in the dataset 
data["Price"] = data["Price"].str.replace("$", "")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16808\1967011825.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Price"] = data["Price"].str.replace("$", "")

# %%
# Calling the unique values of the column after Replacing unwanted characters.
data["Price"].unique()
# Out:
# array(['0', '4.99', '6.99', '7.99', '3.99', '5.99', '2.99', '1.99',
#        '9.99', '0.99', '9.00', '5.49', '10.00', '24.99', '11.99', '79.99',
#        '16.99', '14.99', '29.99', '12.99', '3.49', '10.99', '7.49',
#        '1.50', '19.99', '15.99', '33.99', '39.99', '2.49', '4.49', '1.70',
#        '1.49', '3.88', '399.99', '17.99', '400.00', '3.02', '1.76',
#        '4.84', '4.77', '1.61', '1.59', '6.49', '1.29', '299.99', '379.99',
#        '37.99', '18.99', '389.99', '8.49', '1.75', '14.00', '2.00',
#        '3.08', '2.59', '19.40', '15.46', '8.99', '3.04', '13.99', '4.29',
#        '3.28', '4.60', '1.00', '2.90', '1.97', '2.56', '1.20'],
#       dtype=object)

# %%
# Conversion of column named Price from Object dtype to the best Suitable dtype.
data["Price"].convert_dtypes()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10833    0
# 10834    0
# 10836    0
# 10837    0
# 10840    0
# Name: Price, Length: 7424, dtype: string

# %% [markdown]
# 12. Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we
# created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated',
# 'Current Ver','Android Ver' columns since which are redundant for our analysis)

# %%
#Getting all the columns of the dataset.
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Rating_category'],
#       dtype='object')

# %%
# Dropping the redundant columns from the datset.
data.drop(["App","Rating","Genres","Last Updated","Current Ver","Android Ver"], axis = 1,inplace = True)

# %%
# Viewing the top 5 records of data after removing the dataset
data.head(5)
# Out:
#          Category   Reviews       Size    Installs  Type Price Content Rating  \
# 0  ART_AND_DESIGN  2.201397   19000000      10,000  Free     0       Everyone
# 1  ART_AND_DESIGN  2.985426   14000000     500,000  Free     0       Everyone
# 2  ART_AND_DESIGN  4.942058  8.7000000   5,000,000  Free     0       Everyone
# 3  ART_AND_DESIGN  5.333737   25000000  50,000,000  Free     0           Teen
# 4  ART_AND_DESIGN  2.985426  2.8000000     100,000  Free     0       Everyone
#
#   Rating_category
# 0            High
# 1            High
# 2            High
# 3            High
# 4            High

# %% [markdown]
# 13. Encode the categorical columns.

# %%
# Getting The info of the columns present in the dataset.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7424 entries, 0 to 10840
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Category         7424 non-null   object
#  1   Reviews          7424 non-null   float64
#  2   Size             7424 non-null   object
#  3   Installs         7424 non-null   object
#  4   Type             7424 non-null   object
#  5   Price            7424 non-null   object
#  6   Content Rating   7424 non-null   object
#  7   Rating_category  7424 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 522.0+ KB

# %%
#Using Label Encoding To Encode Categorical columns.
# 1. Category
# Getting count of Unique categories from Category column.
data.Category.nunique()
# Out:
# 33

# %%
# Creating a list of unique categories.
categories = list(data["Category"].unique())

# %%
categories
# Out:
# ['ART_AND_DESIGN',
#  'AUTO_AND_VEHICLES',
#  'BEAUTY',
#  'BOOKS_AND_REFERENCE',
#  'BUSINESS',
#  'COMICS',
#  'COMMUNICATION',
#  'DATING',
#  'EDUCATION',
#  'ENTERTAINMENT',
#  'EVENTS',
#  'FINANCE',
#  'FOOD_AND_DRINK',
#  'HEALTH_AND_FITNESS',
#  'HOUSE_AND_HOME',
#  'LIBRARIES_AND_DEMO',
#  'LIFESTYLE',
#  'GAME',
#  'FAMILY',
#  'MEDICAL',
#  'SOCIAL',
#  'SHOPPING',
#  'PHOTOGRAPHY',
#  'SPORTS',
#  'TRAVEL_AND_LOCAL',
#  'TOOLS',
#  'PERSONALIZATION',
#  'PRODUCTIVITY',
#  'PARENTING',
#  'WEATHER',
#  'VIDEO_PLAYERS',
#  'NEWS_AND_MAGAZINES',
#  'MAPS_AND_NAVIGATION']

# %%
# Importing Label Encoder in order to perform label encoding.
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
# Transforming the Category Column using Label Encoding.
data["Category"] = labelencoder.fit_transform(data["Category"])

# %%
data.head(50)
# Out:
#     Category   Reviews       Size    Installs  Type Price Content Rating  \
# 0          0  2.201397   19000000      10,000  Free     0       Everyone
# 1          0  2.985426   14000000     500,000  Free     0       Everyone
# 2          0  4.942058  8.7000000   5,000,000  Free     0       Everyone
# 3          0  5.333737   25000000  50,000,000  Free     0           Teen
# 4          0  2.985426  2.8000000     100,000  Free     0       Everyone
# 5          0  2.222716  5.6000000      50,000  Free     0       Everyone
# 6          0  2.250420   19000000      50,000  Free     0       Everyone
# 7          0  4.566025   29000000   1,000,000  Free     0       Everyone
# 8          0  4.139596   33000000   1,000,000  Free     0       Everyone
# 9          0  2.082785  3.1000000      10,000  Free     0       Everyone
# 10         0  4.142389   28000000   1,000,000  Free     0       Everyone
# 11         0  3.943890   12000000   1,000,000  Free     0       Everyone
# 12         0  4.651559   20000000  10,000,000  Free     0           Teen
# 13         0  3.636087   21000000     100,000  Free     0       Everyone
# 14         0  3.181272   37000000     100,000  Free     0       Everyone
# 15         0  1.740363  2.7000000       5,000  Free     0       Everyone
# 16         0  3.560146  5.5000000     500,000  Free     0       Everyone
# 17         0  1.431364   17000000      10,000  Free     0       Everyone
# 18         0  5.288285   39000000   5,000,000  Free     0       Everyone
# 19         0  5.351021   31000000  10,000,000  Free     0       Everyone
# 20         0  2.653213   14000000     100,000  Free     0       Everyone
# 21         0  2.815578   12000000     100,000  Free     0       Everyone
# 22         0  3.886434  4.2000000     500,000  Free     0   Everyone 10+
# 24         0  2.071882   23000000      50,000  Free     0       Everyone
# 25         0  2.283301  6.0000000      10,000  Free     0       Everyone
# 26         0  4.306639   25000000     500,000  Free     0       Everyone
# 27         0  2.307496  6.1000000     100,000  Free     0       Everyone
# 28         0  2.133539  4.6000000      10,000  Free     0       Everyone
# 29         0  2.348305  4.2000000     100,000  Free     0       Everyone
# 30         0  3.049218  9.2000000     100,000  Free     0       Everyone
# 31         0  2.356026  5.2000000      50,000  Free     0       Everyone
# 32         0  3.701999   11000000     100,000  Free     0       Everyone
# 33         0  3.006466   11000000     100,000  Free     0       Everyone
# 34         0  2.547775  4.2000000      10,000  Free     0           Teen
# 35         0  2.751279  9.2000000     100,000  Free     0       Everyone
# 36         0  3.910891   24000000     500,000  Free     0       Everyone
# 38         0  2.198657   11000000      10,000  Free     0       Everyone
# 39         0  2.771587  9.4000000     500,000  Free     0       Everyone
# 40         0  2.068186   15000000      10,000  Free     0       Everyone
# 41         0  2.245513   10000000     100,000  Free     0       Everyone
# 43         0  3.343606  1.2000000     100,000  Free     0       Everyone
# 44         0  1.414973   12000000      10,000  Free     0       Everyone
# 45         0  5.241873   24000000  10,000,000  Free     0       Everyone
# 46         0  3.029384   26000000     100,000  Free     0       Everyone
# 47         0  1.929419  8.0000000     100,000  Free     0       Everyone
# 48         0  2.926857  7.9000000     100,000  Free     0       Everyone
# 49         1  2.564666   25000000     100,000  Free     0       Everyone
# 50         1  3.203577   56000000   1,000,000  Free     0       Everyone
# 51         1  2.453318   57000000     100,000  Free     0       Everyone
# 53         1  2.110590   35000000     100,000  Free     0       Everyone
#
#    Rating_category
# 0             High
# 1             High
# 2             High
# 3             High
# 4             High
# 5             High
# 6             High
# 7             High
# 8             High
# 9             High
# 10            High
# 11            High
# 12            High
# 13            High
# 14            High
# 15             Low
# 16            High
# 17            High
# 18            High
# 19            High
# 20            High
# 21            High
# 22            High
# 24            High
# 25            High
# 26            High
# 27            High
# 28            High
# 29            High
# 30            High
# 31            High
# 32            High
# 33            High
# 34            High
# 35            High
# 36            High
# 38            High
# 39            High
# 40            High
# 41            High
# 43            High
# 44            High
# 45            High
# 46            High
# 47            High
# 48            High
# 49            High
# 50            High
# 51            High
# 53            High

# %%
# Checking the values of all categories after label Encoding.
data.Category.value_counts()
# Out:
# 11    1591
# 14     959
# 29     634
# 23     279
# 20     277
# 18     273
# 12     263
# 28     232
# 25     231
# 4      225
# 24     225
# 6      206
# 15     199
# 27     170
# 21     162
# 26     159
# 30     147
# 3      143
# 7      141
# 31     116
# 19      95
# 8       95
# 13      82
# 9       67
# 1       63
# 17      62
# 0       59
# 32      51
# 16      50
# 5       49
# 22      44
# 10      38
# 2       37
# Name: Category, dtype: int64

# %%
#2. Content Rating
# Getting Unique ratings from Content Rating column.
data["Content Rating"].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
# Transforming the Category Column using Label Encoding.
data["Content Rating"] = labelencoder.fit_transform(data["Content Rating"])

# %%
data.head()
# Out:
#    Category   Reviews       Size    Installs  Type Price  Content Rating  \
# 0         0  2.201397   19000000      10,000  Free     0               1
# 1         0  2.985426   14000000     500,000  Free     0               1
# 2         0  4.942058  8.7000000   5,000,000  Free     0               1
# 3         0  5.333737   25000000  50,000,000  Free     0               4
# 4         0  2.985426  2.8000000     100,000  Free     0               1
#
#   Rating_category
# 0            High
# 1            High
# 2            High
# 3            High
# 4            High

# %%
# Checking the values of all Content Rating after label Encoding.
data["Content Rating"].value_counts()
# Out:
# 1    5958
# 4     832
# 3     332
# 2     299
# 0       2
# 5       1
# Name: Content Rating, dtype: int64

# %%
# for Type
# Getting Unique types from Type column.
data["Type"].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
data.head(5)
# Out:
#    Category   Reviews       Size    Installs  Type Price  Content Rating  \
# 0         0  2.201397   19000000      10,000  Free     0               1
# 1         0  2.985426   14000000     500,000  Free     0               1
# 2         0  4.942058  8.7000000   5,000,000  Free     0               1
# 3         0  5.333737   25000000  50,000,000  Free     0               4
# 4         0  2.985426  2.8000000     100,000  Free     0               1
#
#   Rating_category
# 0            High
# 1            High
# 2            High
# 3            High
# 4            High

# %%
# Transforming the Type Column using Label Encoding.
data["Type"] = labelencoder.fit_transform(data["Type"])

# %%
# Checking the values of all Type after label Encoding.
data["Type"].value_counts()
# Out:
# 0    6877
# 1     547
# Name: Type, dtype: int64

# %%
data.head()
# Out:
#    Category   Reviews       Size    Installs  Type Price  Content Rating  \
# 0         0  2.201397   19000000      10,000     0     0               1
# 1         0  2.985426   14000000     500,000     0     0               1
# 2         0  4.942058  8.7000000   5,000,000     0     0               1
# 3         0  5.333737   25000000  50,000,000     0     0               4
# 4         0  2.985426  2.8000000     100,000     0     0               1
#
#   Rating_category
# 0            High
# 1            High
# 2            High
# 3            High
# 4            High

# %%
#4.Rating Category
# Getting Unique categories from Rating_category column.
data["Rating_category"].unique()
# Out:
# array([0, 1])

# %%
data.head(2)
# Out:
#    Category   Reviews      Size Installs  Type Price  Content Rating  \
# 0         0  2.201397  19000000   10,000     0     0               1
# 1         0  2.985426  14000000  500,000     0     0               1
#
#    Rating_category
# 0                0
# 1                0

# %%
data["Rating_category"].value_counts()
# Out:
# 0    6599
# 1     825
# Name: Rating_category, dtype: int64

# %%
# Transforming the Rating_category Column using Label Encoding.
data["Rating_category"] = labelencoder.fit_transform(data["Rating_category"])

# %%
# Checking the values of all Rating_category after label Encoding.
data["Rating_category"].value_counts()
# Out:
# 0    6599
# 1     825
# Name: Rating_category, dtype: int64

# %%
data.head()
# Out:
#    Category   Reviews       Size    Installs  Type Price  Content Rating  \
# 0         0  2.201397   19000000      10,000     0     0               1
# 1         0  2.985426   14000000     500,000     0     0               1
# 2         0  4.942058  8.7000000   5,000,000     0     0               1
# 3         0  5.333737   25000000  50,000,000     0     0               4
# 4         0  2.985426  2.8000000     100,000     0     0               1
#
#    Rating_category
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# 14. Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
# Creating variable X with all Independent Variables.
X = data.drop("Rating_category", axis=1)

# Creating variable Y with Dependent Variable.
Y = data[["Rating_category"]]

# %%
X
# Out:
#        Category   Reviews       Size    Installs  Type Price  Content Rating
# 0             0  2.201397   19000000      10,000     0     0               1
# 1             0  2.985426   14000000     500,000     0     0               1
# 2             0  4.942058  8.7000000   5,000,000     0     0               1
# 3             0  5.333737   25000000  50,000,000     0     0               4
# 4             0  2.985426  2.8000000     100,000     0     0               1
# ...         ...       ...        ...         ...   ...   ...             ...
# 10833         3  1.643453     619000       1,000     0     0               1
# 10834        11  0.845098  2.6000000         500     0     0               1
# 10836        11  1.579784   53000000       5,000     0     0               1
# 10837        11  0.602060  3.6000000         100     0     0               1
# 10840        18  5.600218   19000000  10,000,000     0     0               1
#
# [7424 rows x 7 columns]

# %%
Y
# Out:
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10833                0
# 10834                0
# 10836                0
# 10837                0
# 10840                0
#
# [7424 rows x 1 columns]

# %% [markdown]
# 15. Split the dataset into train and test.

# %%
# importing library to splitting the dataset.
from sklearn.model_selection import train_test_split

# %%
#Spliting the data set into Train and Test.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30 , random_state=1)

# %%
print("X_train")
X_train
print("X_test")
X_test
print("Y_train")
Y_train
print("Y_test")
Y_test
# Out:
# X_train
#       Category   Reviews       Size     Installs  Type Price  Content Rating
# 8888         0  0.000000  2.9000000          100     0     0               1
# 1298        15  5.264019   57000000    5,000,000     0     0               1
# 6599        20  2.489958  5.9000000       10,000     0     0               1
# 7328        30  2.328380  6.1000000        5,000     1  3.99               1
# 5681        18  1.755875  5.8000000       10,000     0     0               1
# ...        ...       ...        ...          ...   ...   ...             ...
# 1522        17  2.731589   99000000       50,000     0     0               1
# 7755        11  1.462398   37000000        1,000     0     0               2
# 5978        11  0.000000  2.0000000           50     1  1.49               1
# 347          6  6.679963   11000000  500,000,000     0     0               1
# 7698        14  0.698970   12000000          100     0     0               1
#
# [5196 rows x 7 columns]
# X_test
#        Category   Reviews       Size   Installs  Type Price  Content Rating
# 5708         29  2.845718  7.3000000    100,000     0     0               1
# 7215         11  2.559907   14000000      1,000     1  2.99               2
# 1350         15  4.852901   49000000  1,000,000     0     0               1
# 5727         29  4.895583  6.3000000  1,000,000     0     0               1
# 5326         11  3.997910  3.7000000    100,000     0     0               4
# ...         ...       ...        ...        ...   ...   ...             ...
# 6351         29  3.066699     350000    100,000     0     0               1
# 1634         18  3.493319   13000000    100,000     0     0               1
# 9865          3  1.518514   37000000      1,000     0     0               1
# 10396        11  5.345748   94000000  5,000,000     0     0               4
# 6550         11  1.812913   24000000     10,000     0     0               1
#
# [2228 rows x 7 columns]
# Y_train
#       Rating_category
# 8888                0
# 1298                0
# 6599                0
# 7328                0
# 5681                0
# ...               ...
# 1522                0
# 7755                0
# 5978                1
# 347                 0
# 7698                0
#
# [5196 rows x 1 columns]
# Y_test
#        Rating_category
# 5708                 0
# 7215                 0
# 1350                 0
# 5727                 0
# 5326                 0
# ...                ...
# 6351                 0
# 1634                 0
# 9865                 0
# 10396                0
# 6550                 0
#
# [2228 rows x 1 columns]

# %%
X_train
# Out:
#       Category   Reviews       Size     Installs  Type Price  Content Rating
# 8888         0  0.000000  2.9000000          100     0     0               1
# 1298        15  5.264019   57000000    5,000,000     0     0               1
# 6599        20  2.489958  5.9000000       10,000     0     0               1
# 7328        30  2.328380  6.1000000        5,000     1  3.99               1
# 5681        18  1.755875  5.8000000       10,000     0     0               1
# ...        ...       ...        ...          ...   ...   ...             ...
# 1522        17  2.731589   99000000       50,000     0     0               1
# 7755        11  1.462398   37000000        1,000     0     0               2
# 5978        11  0.000000  2.0000000           50     1  1.49               1
# 347          6  6.679963   11000000  500,000,000     0     0               1
# 7698        14  0.698970   12000000          100     0     0               1
#
# [5196 rows x 7 columns]

# %%
X_test
# Out:
#        Category   Reviews       Size   Installs  Type Price  Content Rating
# 5708         29  2.845718  7.3000000    100,000     0     0               1
# 7215         11  2.559907   14000000      1,000     1  2.99               2
# 1350         15  4.852901   49000000  1,000,000     0     0               1
# 5727         29  4.895583  6.3000000  1,000,000     0     0               1
# 5326         11  3.997910  3.7000000    100,000     0     0               4
# ...         ...       ...        ...        ...   ...   ...             ...
# 6351         29  3.066699     350000    100,000     0     0               1
# 1634         18  3.493319   13000000    100,000     0     0               1
# 9865          3  1.518514   37000000      1,000     0     0               1
# 10396        11  5.345748   94000000  5,000,000     0     0               4
# 6550         11  1.812913   24000000     10,000     0     0               1
#
# [2228 rows x 7 columns]

# %%
Y_train
# Out:
#       Rating_category
# 8888                0
# 1298                0
# 6599                0
# 7328                0
# 5681                0
# ...               ...
# 1522                0
# 7755                0
# 5978                1
# 347                 0
# 7698                0
#
# [5196 rows x 1 columns]

# %%
Y_test
# Out:
#        Rating_category
# 5708                 0
# 7215                 0
# 1350                 0
# 5727                 0
# 5326                 0
# ...                ...
# 6351                 0
# 1634                 0
# 9865                 0
# 10396                0
# 6550                 0
#
# [2228 rows x 1 columns]

# %% [markdown]
# 16. Standardize the data, so that the values are within a particular range.

# %%
#Importing necessary libraries to Standardize the data.
from sklearn.preprocessing import StandardScaler

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7424 entries, 0 to 10840
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Category         7424 non-null   int32
#  1   Reviews          7424 non-null   float64
#  2   Size             7424 non-null   object
#  3   Installs         7424 non-null   object
#  4   Type             7424 non-null   int32
#  5   Price            7424 non-null   object
#  6   Content Rating   7424 non-null   int32
#  7   Rating_category  7424 non-null   int64
# dtypes: float64(1), int32(3), int64(1), object(3)
# memory usage: 435.0+ KB

# %% [markdown]
# #### Since the columns named as Size, Installs, Price are of object data type, we need to convert the data to int dtype in order to perform Standardizing

# %%
data['Installs'] = data['Installs'].apply(lambda x : x.replace(',','').replace('+','')).astype(int)

# %%
data['Size'] = data['Size'].apply(lambda x : x.replace(',','')).astype(float)

# %%
data['Price'] = data['Price'].apply(lambda x : x.replace(',','')).astype(float)

# %%
#defining standard scaler
scaler = StandardScaler()

# %%
# Performing Standardization of data
data1 = scaler.fit_transform(data)

# %%
#Calling our numpy arrays after performing Standardization
data1
# Out:
# array([[-2.03766618, -0.67995305, -0.07422317, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [-2.03766618, -0.19653147, -0.27499084, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [-2.03766618,  1.0099001 , -0.83713998, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        ...,
#        [-0.68621673, -1.0632313 ,  1.29099702, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [-0.68621673, -1.66608206, -0.83714018, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [ 0.17379656,  1.41571255, -0.07422317, ..., -0.06305842,
#         -0.46322046, -0.35358018]])

# %%
# Converting Array's back to Pandas DataFrame.
data2 = pd.DataFrame(data1)

# %%
data2
# Out:
#              0         1         2         3         4         5         6  \
# 0    -2.037666 -0.679953 -0.074223 -0.168764 -0.282029 -0.063058 -0.463220
# 1    -2.037666 -0.196531 -0.274991 -0.158181 -0.282029 -0.063058 -0.463220
# 2    -2.037666  1.009900 -0.837140 -0.060990 -0.282029 -0.063058 -0.463220
# 3    -2.037666  1.251404  0.166698  0.910911 -0.282029 -0.063058  2.517665
# 4    -2.037666 -0.196531 -0.837140 -0.166820 -0.282029 -0.063058 -0.463220
# ...        ...       ...       ...       ...       ...       ...       ...
# 7419 -1.669089 -1.023974 -0.812285 -0.168958 -0.282029 -0.063058 -0.463220
# 7420 -0.686217 -1.516228 -0.837140 -0.168969 -0.282029 -0.063058 -0.463220
# 7421 -0.686217 -1.063231  1.290997 -0.168872 -0.282029 -0.063058 -0.463220
# 7422 -0.686217 -1.666082 -0.837140 -0.168977 -0.282029 -0.063058 -0.463220
# 7423  0.173797  1.415713 -0.074223  0.046999 -0.282029 -0.063058 -0.463220
#
#             7
# 0    -0.35358
# 1    -0.35358
# 2    -0.35358
# 3    -0.35358
# 4    -0.35358
# ...       ...
# 7419 -0.35358
# 7420 -0.35358
# 7421 -0.35358
# 7422 -0.35358
# 7423 -0.35358
#
# [7424 rows x 8 columns]

# %% [markdown]
# ## Sweetviz Interactive Dashboard of the Google Play Store Analysis Data.

# %% [markdown]
# In order to get a better understanding of the data after its transformation and Data Analysis, a interactive dashboard is added using sweetviz Library

# %%
data.head()
# Out:
#    Category   Reviews        Size  Installs  Type  Price  Content Rating  \
# 0         0  2.201397  19000000.0     10000     0    0.0               1
# 1         0  2.985426  14000000.0    500000     0    0.0               1
# 2         0  4.942058         8.7   5000000     0    0.0               1
# 3         0  5.333737  25000000.0  50000000     0    0.0               4
# 4         0  2.985426         2.8    100000     0    0.0               1
#
#    Rating_category
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
Playstore_analysis_report=sweetviz.analyze(data2)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
Playstore_analysis_report.show_html("Playstore_analysis_report.html")
# Out:
# Report Playstore_analysis_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
